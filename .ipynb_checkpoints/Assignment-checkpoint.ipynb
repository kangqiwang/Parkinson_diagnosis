# %%
import torch
from torch import nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.autograd import Variable
from sklearn.preprocessing import scale
import numpy as np
import torch.nn.functional as F

EPOCH = 1               # train the training data n times, to save time, we just train 1 epoch
N_HIDDEN=200

test_data=np.loadtxt('test_data.txt',dtype='float',delimiter=',')
train_data=np.loadtxt('train_data.txt',dtype='float64',delimiter=',')
x_target=train_data[:,28]
y_target=test_data[:,27]
test_data=np.delete(test_data,27,1)
train_data=np.delete(train_data,28,1)
train_data=np.delete(train_data,27,1)
train_data=np.delete(train_data,0,1)
test_data=np.delete(test_data,0,1)

#x,y=np.concatenate((train_data,test_data),axis=0),np.concatenate((x_target,y_target),axis=0)
x=train_data
y=x_target

x,test_data=scale(x),scale(test_data)



x,y=torch.from_numpy(x).type(torch.FloatTensor),torch.from_numpy(y).type(torch.LongTensor)

x, y = Variable(x), Variable(y)

print(x,'\n')
print(y)



net = torch.nn.Sequential(
    torch.nn.Linear(26, N_HIDDEN),
    torch.nn.Dropout(0.3),  # drop 50% of the neuron
    torch.nn.ReLU(),    
    torch.nn.Linear(N_HIDDEN, N_HIDDEN),
    torch.nn.Dropout(0.3),  # drop 50% of the neuron
    torch.nn.ReLU(),
    torch.nn.Linear(N_HIDDEN, 2),
)

'''
class Net(torch.nn.Module):
    def __init__(self, n_feature, n_hidden, n_output):
        super(Net, self).__init__()
        self.hidden = torch.nn.Linear(n_feature, n_hidden)   # hidden layer
        self.out = torch.nn.Linear(n_hidden, n_output)   # output layer

    def forward(self, x):
        x = F.relu(self.hidden(x))      # activation function for hidden layer
        x = self.out(x)
        return x

net = Net(n_feature=26, n_hidden=1000, n_output=2)     # define the network
  '''

  


print(net)  # net architecture

optimizer = torch.optim.Adam(net.parameters(), lr=0.02)
loss_func = torch.nn.CrossEntropyLoss()  # the target label is NOT an one-hotted

for t in range(500):
    out = net(x)
    #print(out)
    loss=loss_func(out,y)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 50==0:
        net.eval()
        #test_net=net(test_x)
        prediction = torch.max(out, 1)[1]
        pred_y = prediction.data.numpy().squeeze()
        target_y = y.data.numpy()
        TP=0
        TN=0
        FN=0
        FP=0
        for i in range(len(pred_y)):
            TP += ((pred_y[i] == 1) & (target_y[i] == 1))
            TN += ((pred_y[i] == 0) & (target_y[i] == 0))
            FN += ((pred_y[i] == 0) & (target_y[i] == 1))
            FP += ((pred_y[i] == 1) & (target_y[i] == 0))
        p = TP / (TP + FP)
        r = TP / (TP + FN)
        F1 = 2 * r * p / (r + p)
        acc = (TP + TN) / (TP + TN + FP + FN)
        print('this is F1 scorce    ',F1 )
        print('this is acc          ',acc )
        net.train()

'''
print('this is my x     ',x,'this is my y       ',y )

print(test_data)
print('this is my second data')
print('this is my shape',test_data.shape)
print('this is my shape',train_data.shape)
print('this is my target x data     ',x_target.shape,'   this is my target y data',y_target.shape)
print('\n')
print(train_data)
print('\n')

y0 = torch.zeros(100)   
print(y0)
'''
# Out:
# Variable containing:
# -6.7539e-01 -7.5360e-01 -3.5450e-01  ...  -1.3204e+00 -7.0299e-01 -8.1626e-01
# -1.1062e+00 -1.2471e+00 -9.1324e-01  ...  -1.2132e+00 -7.0299e-01 -8.1626e-01
# -8.2730e-01 -9.0558e-01 -5.2611e-01  ...  -8.1215e-01 -8.3405e-02 -8.0451e-01
#                 ...                   ⋱                   ...
#  1.3177e-01  5.2449e-01 -1.0833e-01  ...  -3.6646e-01 -8.3405e-02 -5.1443e-01
#  6.2832e-01  9.8197e-01  5.5051e-01  ...  -5.2544e-01  1.1558e+00  4.7543e-01
# -4.9344e-01 -2.0571e-01 -5.7922e-01  ...  -4.5317e-01 -8.3405e-02 -5.9276e-01
# [torch.FloatTensor of size 1040x26]
#
#
# Variable containing:
#  1
#  1
#  1
# ⋮
#  0
#  0
#  0
# [torch.LongTensor of size 1040]
#
# Sequential(
#   (0): Linear(in_features=26, out_features=200, bias=True)
#   (1): Dropout(p=0.3)
#   (2): ReLU()
#   (3): Linear(in_features=200, out_features=200, bias=True)
#   (4): Dropout(p=0.3)
#   (5): ReLU()
#   (6): Linear(in_features=200, out_features=2, bias=True)
# )
# this is F1 scorce     0.4809384164222874
# this is acc           0.4894230769230769
# this is F1 scorce     0.7495769881556684
# this is acc           0.7153846153846154
# this is F1 scorce     0.798598949211909
# this is acc           0.7788461538461539
# this is F1 scorce     0.8568840579710145
# this is acc           0.8480769230769231
# this is F1 scorce     0.8662533215234721
# this is acc           0.8548076923076923
# this is F1 scorce     0.8942486085343229
# this is acc           0.8903846153846153
# this is F1 scorce     0.9052437902483901
# this is acc           0.9009615384615385
# this is F1 scorce     0.901535682023487
# this is acc           0.8951923076923077
# this is F1 scorce     0.9117647058823529
# this is acc           0.9076923076923077
# this is F1 scorce     0.92018779342723
# this is acc           0.9182692307692307
# "\nprint('this is my x     ',x,'this is my y       ',y )\n\nprint(test_data)\nprint('this is my second data')\nprint('this is my shape',test_data.shape)\nprint('this is my shape',train_data.shape)\nprint('this is my target x data     ',x_target.shape,'   this is my target y data',y_target.shape)\nprint('\n')\nprint(train_data)\nprint('\n')\n\ny0 = torch.zeros(100)   \nprint(y0)\n"

# %%
import torch
from torch import nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from torch.autograd import Variable
from sklearn.preprocessing import scale
import numpy as np
import torch.nn.functional as F

EPOCH = 1               # train the training data n times, to save time, we just train 1 epoch
N_HIDDEN=200

test_data=np.loadtxt('test_data.txt',dtype='float',delimiter=',')
train_data=np.loadtxt('train_data.txt',dtype='float64',delimiter=',')
x_target=train_data[:,28]
y_target=test_data[:,27]
test_data=np.delete(test_data,27,1)
train_data=np.delete(train_data,28,1)
train_data=np.delete(train_data,27,1)
train_data=np.delete(train_data,0,1)
test_data=np.delete(test_data,0,1)

#x,y=np.concatenate((train_data,test_data),axis=0),np.concatenate((x_target,y_target),axis=0)
x=train_data
y=x_target

x,test_data=scale(x),scale(test_data)



x,y=torch.from_numpy(x).type(torch.FloatTensor),torch.from_numpy(y).type(torch.LongTensor)

x, y = Variable(x), Variable(y)

print(x,'\n')
print(y)

'''

net = torch.nn.Sequential(
    torch.nn.Linear(26, N_HIDDEN),
    torch.nn.Dropout(0.3),  # drop 50% of the neuron
    torch.nn.ReLU(),    
    torch.nn.Linear(N_HIDDEN, N_HIDDEN),
    torch.nn.Dropout(0.3),  # drop 50% of the neuron
    torch.nn.ReLU(),
    torch.nn.Linear(N_HIDDEN, 2),
)
'''

class Net(torch.nn.Module):
    def __init__(self, n_feature, n_hidden, n_output):
        super(Net, self).__init__()
        self.hidden = torch.nn.Linear(n_feature, n_hidden)   # hidden layer
        self.out = torch.nn.Linear(n_hidden, n_output)   # output layer

    def forward(self, x):
        x = F.relu(self.hidden(x))      # activation function for hidden layer
        x = self.out(x)
        return x

net = Net(n_feature=26, n_hidden=1000, n_output=2)     # define the network
  

  


print(net)  # net architecture

optimizer = torch.optim.Adam(net.parameters(), lr=0.02)
loss_func = torch.nn.CrossEntropyLoss()  # the target label is NOT an one-hotted

for t in range(500):
    out = net(x)
    #print(out)
    loss=loss_func(out,y)
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    if t % 50==0:
        net.eval()
        #test_net=net(test_x)
        prediction = torch.max(out, 1)[1]
        pred_y = prediction.data.numpy().squeeze()
        target_y = y.data.numpy()
        TP=0
        TN=0
        FN=0
        FP=0
        for i in range(len(pred_y)):
            TP += ((pred_y[i] == 1) & (target_y[i] == 1))
            TN += ((pred_y[i] == 0) & (target_y[i] == 0))
            FN += ((pred_y[i] == 0) & (target_y[i] == 1))
            FP += ((pred_y[i] == 1) & (target_y[i] == 0))
        p = TP / (TP + FP)
        r = TP / (TP + FN)
        F1 = 2 * r * p / (r + p)
        acc = (TP + TN) / (TP + TN + FP + FN)
        print('this is F1 scorce    ',F1 )
        print('this is acc          ',acc )
        net.train()

'''
print('this is my x     ',x,'this is my y       ',y )

print(test_data)
print('this is my second data')
print('this is my shape',test_data.shape)
print('this is my shape',train_data.shape)
print('this is my target x data     ',x_target.shape,'   this is my target y data',y_target.shape)
print('\n')
print(train_data)
print('\n')

y0 = torch.zeros(100)   
print(y0)
'''
# Out:
# Variable containing:
# -6.7539e-01 -7.5360e-01 -3.5450e-01  ...  -1.3204e+00 -7.0299e-01 -8.1626e-01
# -1.1062e+00 -1.2471e+00 -9.1324e-01  ...  -1.2132e+00 -7.0299e-01 -8.1626e-01
# -8.2730e-01 -9.0558e-01 -5.2611e-01  ...  -8.1215e-01 -8.3405e-02 -8.0451e-01
#                 ...                   ⋱                   ...
#  1.3177e-01  5.2449e-01 -1.0833e-01  ...  -3.6646e-01 -8.3405e-02 -5.1443e-01
#  6.2832e-01  9.8197e-01  5.5051e-01  ...  -5.2544e-01  1.1558e+00  4.7543e-01
# -4.9344e-01 -2.0571e-01 -5.7922e-01  ...  -4.5317e-01 -8.3405e-02 -5.9276e-01
# [torch.FloatTensor of size 1040x26]
#
#
# Variable containing:
#  1
#  1
#  1
# ⋮
#  0
#  0
#  0
# [torch.LongTensor of size 1040]
#
# Net(
#   (hidden): Linear(in_features=26, out_features=1000, bias=True)
#   (out): Linear(in_features=1000, out_features=2, bias=True)
# )
# this is F1 scorce     0.562358276643991
# this is acc           0.44326923076923075
# this is F1 scorce     0.8030447193149381
# this is acc           0.8009615384615385
# this is F1 scorce     0.9317561419472248
# this is acc           0.9278846153846154
# this is F1 scorce     0.9914040114613181
# this is acc           0.9913461538461539
# this is F1 scorce     0.9980769230769231
# this is acc           0.9980769230769231
# this is F1 scorce     0.9990375360923965
# this is acc           0.9990384615384615
# this is F1 scorce     1.0
# this is acc           1.0
# this is F1 scorce     1.0
# this is acc           1.0
